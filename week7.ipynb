# %%
#week-7
#l-19
#Classes
#Example
class Dog:
    """A simple attempt to model a dog """
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def sit(self):
        """ Simulate a dog sitting in response to a command"""
        print(f"{self.name}  is now sitting")
        
    def roll_over (self):
        """ Simulate rolling over is response to a command"""
        print(f"{self.name} rolled over")
        
my_dog=Dog('chintu',6)
your_dog=Dog('chinky',3)

print(f"My dog's name is {my_dog.name}")
print(f"My dog is {my_dog.age} years old")
my_dog.sit()
my_dog.roll_over()

print(f"your dog's is {your_dog.name}")
print(f"Your dog is {your_dog.age} years old")
your_dog.sit()
your_dog.roll_over()
# Out:
# My dog's name is chintu
# My dog is 6 years old
# chintu  is now sitting
# chintu rolled over
# your dog's is chinky
# Your dog is 3 years old
# chinky  is now sitting
# chinky rolled over

# %%
#Default value for an attribute
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0 #default value
        
    def get_describe_name(self):
        """ Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """ Print a stasement showing the car mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it.")

        
my_new_car=Car('toyota','innovo',2019)
print(my_new_car.get_describe_name())
my_new_car.read_odometer()
# Out:
# 2019 Toyota Innovo
# This car has 0 kilometer on it.

# %%
#Modifying Attrubute values
#One Way-Modifying  an Attrubute's values directly
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0 #default value
        
    def get_describe_name(self):
        """ Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """ Print a stasement showing the car mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it.")

        
my_new_car=Car('toyota','innovo',2019)
print(my_new_car.get_describe_name())
my_new_car.odometer_reading=23
my_new_car.read_odometer()
# Out:
# 2019 Toyota Innovo
# This car has 23 kilometer on it.

# %%
# 2nd way-#One Way-Modifying  an Attrubute's values though a method
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0 #default value
        
    def get_describe_name(self):
        """ Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """ Print a stasement showing the car mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it.")
        
    def update_odometer(self,mileage):
        """ set the odometer reading to the given value."""
        self.odometer_reading=mileage

        
my_new_car=Car('toyota','innovo',2019)
print(my_new_car.get_describe_name())

my_new_car.update_odometer(33)
my_new_car.read_odometer()
# Out:
# 2019 Toyota Innovo
# This car has 33 kilometer on it.

# %%
# Examples:-
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it")
        
    def update_odometer(self,mileage):
        """Set the odometer reading to the given value.Rejected the change if it aatempt to roll the odometer back"""
        if mileage>=self.odometer_reading:
            self.odometer_reading=mileage
        else:
            print("you can't roll back an odometer!")
    def increment_odometer(self,miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading+=miles

my_used_car=Car('innova','suv',2015)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(500)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()
# Out:
# 2015 Innova Suv
# This car has 500 kilometer on it
# This car has 600 kilometer on it

# %%
#Inheritance
#Example-
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it")
        
    def update_odometer(self,mileage):
        """Set the odometer reading to the given value.Rejected the change if it aatempt to roll the odometer back"""
        if mileage>=self.odometer_reading:
            self.odometer_reading=mileage
        else:
            print("you can't roll back an odometer!")
    def increment_odometer(self,miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading+=miles
class ElectricCar(Car):
    """Represent aspects of a car,specific to electric vihicles"""
    
    def __init__(self,make,model,year):
        """Initialize aattibutes of the parent class"""
        super().__init__(make,model,year)
   
    
my_hyundai=ElectricCar('hyundai','kona',2019)
print(my_hyundai.get_descriptive_name())
# Out:
# 2019 Hyundai Kona

# %%
#Defining attributes and methods for child class
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it")
        
    def update_odometer(self,mileage):
        """Set the odometer reading to the given value.Rejected the change if it aatempt to roll the odometer back"""
        if mileage>=self.odometer_reading:
            self.odometer_reading=mileage
        else:
            print("you can't roll back an odometer!")
    def increment_odometer(self,miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading+=miles
class ElectricCar(Car):
    """Represent aspects of a car,specific to electric vihicles"""
    
    def __init__(self,make,model,year):
        """Initialize aattibutes of the parent class"""
        super().__init__(make,model,year)
        self.battery_size=64
        
    def describe_battery(self):
        """Print a statement descripting the battery size"""
        print(f"This car has a {self.battery_size} kwh battery")
        
my_hyundai=ElectricCar('hyundai','kona',2019)
print(my_hyundai.get_descriptive_name())
my_hyundai.describe_battery()
# Out:
# 2019 Hyundai Kona
# This car has a 64 kwh battery

# %%
#Instance as attributes:-
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it")
        
    def update_odometer(self,mileage):
        """Set the odometer reading to the given value.Rejected the change if it aatempt to roll the odometer back"""
        if mileage>=self.odometer_reading:
            self.odometer_reading=mileage
        else:
            print("you can't roll back an odometer!")
    def increment_odometer(self,miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading+=miles
        
class Battery:
    """a simple attempt to a battery for an electric car"""
    def __init__(self,battery_size=64):
        """Initialize the battery's aattributs"""
        self.battery_size=battery_size
        
    def describe_battrery(self):
        """Print a statment describe the battery size"""
        print(f"This car has a {self.battery_size}-kwh battery")
class ElectricCar(Car):
    """Represent aspects of a car,specific to electric vihicles"""
    
    def __init__(self,make,model,year):
        """Initialize aattibutes of the parent class"""
        super().__init__(make,model,year)
        self.battery_size=64
        
    def describe_battery(self):
        """Print a statement descripting the battery size"""
        print(f"This car has aa {self.battery_size} kwh battery")
        
    def filgas_tank(self):
        """Electric cars don't have diesel tanks"""
        print("this car doesn't need a diesel tank")
        
my_hyundai=ElectricCar('hyundai','kona',2019)
print(my_hyundai.get_descriptive_name())
                       
my_hyundai.describe_battery()
# Out:
# 2019 Hyundai Kona
# This car has aa 64 kwh battery

# %%
#Instance as attributes:-
class Car:
    """ Simulate a dog sitting in response to a command"""
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name=(f"{self.year} {self.make} {self.model}")
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage"""
        print(f"This car has {self.odometer_reading} kilometer on it")
        
    def update_odometer(self,mileage):
        """Set the odometer reading to the given value.Rejected the change if it aatempt to roll the odometer back"""
        if mileage>=self.odometer_reading:
            self.odometer_reading=mileage
        else:
            print("you can't roll back an odometer!")
    def increment_odometer(self,miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading+=miles
        
class Battery:
    """a simple attempt to a battery for an electric car"""
    def __init__(self,battery_size=64):
        """Initialize the battery's aattributs"""
        self.battery_size=battery_size
        
    def get_range(self):
        """Print a statement about the range this battery provodes"""
        if self.battery_size==64:
            range=260
        elif self.battery_size==100:
            
            range=315
        print(f"This car go about {range} kilimeter 0n a full charge")
        
    def describe_battery(self):
        """Print a statment describe the battery size"""
        print(f"This car has a {self.battery_size}-kwh battery")
class ElectricCar(Car):
    """Represent aspects of a car,specific to electric vihicles"""
    
    def __init__(self,make,model,year):
        """Initialize aattibutes of the parent class"""
        super().__init__(make,model,year)
        self.battery=Battery()
        
    def describe_battery(self):
        """Print a statement descripting the battery size"""
        print(f"This car has aa {self.battery_size} kwh battery")
        
    def filgas_tank(self):
        """Electric cars don't have diesel tanks"""
        print("this car doesn't need a diesel tank")
        
my_hyundai=ElectricCar('hyundai','kona',2019)
print(my_hyundai.get_descriptive_name())

                       
my_hyundai.battery.get_range()
# Out:
# 2019 Hyundai Kona
# This car go about 260 kilimeter 0n a full charge
